# %% [markdown]
# <a href="https://colab.research.google.com/github/iiconic07/iiconic07/blob/main/EXTRACTING_DATA_FROM_PDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install "camelot-py"[cv]
# Out:
# ...
#      |████████████████████████████████| 40 kB 12 kB/s
# ...
#      |████████████████████████████████| 5.6 MB 13.7 MB/s
# ...
#      |████████████████████████████████| 77 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 11.7 MB 41.8 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 41.4 MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61102 sha256=b60cc29fc320e33db761c41d70b11f6e990779f7fb05f20bb40a4ebb69c0eb4e
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...

# %%
# !apt-get install ghostscript
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono gsfonts libcupsfilters1 libcupsimage2
#   libgs9 libgs9-common libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x poppler-utils fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 11 newly installed, 0 to remove and 39 not upgraded.
# Need to get 14.1 MB of archives.
# After this operation, 49.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# ...

# %%
import camelot as cam

# %%
# extracting data from pdf

table = cam.read_pdf("Cap1.pdf", pages = '2',flavor = 'stream')

# %%
table
# Out:
# <TableList n=1>

# %%
table[0].df.to_csv("project-excel.csv")

# %%
df = pd.read_csv("project-excel.csv" )

# %%
df
# Out:
#     Unnamed: 0                                                  0  \
# 0            0                                                NaN
# 1            1                                              D i r
# 2            2                                                NaN
# 3            3                                                NaN
# 4            4                                                NaN
# 5            5                                                NaN
# 6            6                                            Status:
# 7            7                                                NaN
# 8            8                                              Stage
# 9            9                                                NaN
# 10          10                                                  I
# 11          11                                                NaN
# 12          12                                                NaN
# ...

# %%
df1 = df.drop("Unnamed: 0",axis=1)

# %%
df1
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                               D i r
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                             Status:
# 7                                                 NaN
# 8                                               Stage
# 9                                                 NaN
# 10                                                  I
# 11                                                NaN
# 12                                                NaN
# 13                                            Status:
# 14                                                NaN
# 15                                              Stage
# ...

# %%
#cleaning data (program-name)

program = df1.loc[4]

# %%
df2=df1.loc[5]

# %%
df3=df2.iloc[1:2]

# %%
df3.dropna
# Out:
# <bound method Series.dropna of 1    100246610 - Instrumentation Engineering
# Name: 5, dtype: object>

# %%
#closing-Rank

df4=df1.loc[9]

# %%
df5=df4.iloc[1:16]

# %%
df5.dropna
# Out:
# <bound method Series.dropna of 1      7194
# 2     14267
# 3     33295
# 4     13821
# 5      9776
# 6     14168
# 7     13239
# 8      8849
# 9     11544
# 10    11926
# 11    18357
# 12    85591
# 13    14226
# 14    21098
# 15    12158
# Name: 16, dtype: object>

# %%
#closing percentile

df6=df1.iloc[11]

# %%
df7=df6.iloc[1:16]

# %%
df7.dropna
# Out:
# <bound method Series.dropna of 1     (93.5194774)
# 2     (85.9439612)
# 3     (49.2624002)
# 4     (88.5891094)
# 5     (92.1547185)
# 6     (82.5517986)
# 7     (93.2348660)
# 8     (86.0540400)
# 9     (74.6087498)
# 10    (88.5735391)
# 11    (80.7275334)
# 12    (92.7054742)
# 13    (74.6601682)
# 14    (43.5611190)
# 15    (94.8226791)
# Name: 11, dtype: object>

# %%
#college NAME

df8=df1.loc[4]

# %%
df9=df8.iloc[1:2]

# %%
df9.dropna
# Out:
# <bound method Series.dropna of 1    1002 - Government College of Engineering, Amra...
# Name: 4, dtype: object>

# %%
df9
# Out:
# 1    1002 - Government College of Engineering, Amra...
# Name: 4, dtype: object

# %%
#Category

df10=df1.loc[8]

# %%
df11 = df10.iloc[1:16]

# %%
df11.dropna
# Out:
# <bound method Series.dropna of 1     GOPENS
# 2       GSCS
# 3       GSTS
# 4      GNT2S
# 5      GOBCS
# 6     GSEBCS
# 7     LOPENS
# 8       LSCS
# 9       LSTS
# 10     LNT1S
# 11     LNT2S
# 12     LOBCS
# 13    LSEBCS
# 14       EWS
# 15      TFWS
# Name: 8, dtype: object>

# %%
#arranging the useful data 

CAP= pd.DataFrame({ "Institute Name": df9, "Category": df11 , "Program":df3,"Closing-Rank":df5,"Closing-Percentile":df7})

# %%
CAP
# Out:
#                                        Institute Name Category  \
# 1   1002 - Government College of Engineering, Amra...   GOPENS
# 10                                                NaN    LNT1S
# 11                                                NaN    LNT2S
# 12                                                NaN    LOBCS
# 13                                                NaN   LSEBCS
# 14                                                NaN      EWS
# 15                                                NaN     TFWS
# 2                                                 NaN     GSCS
# 3                                                 NaN     GSTS
# 4                                                 NaN    GNT2S
# 5                                                 NaN    GOBCS
# 6                                                 NaN   GSEBCS
# 7                                                 NaN   LOPENS
# 8                                                 NaN     LSCS
# ...

# %%
#reseting index

del CAP['index']

# %%
CAP
# Out:
#                                        Institute Name Category  \
# 0   1002 - Government College of Engineering, Amra...   GOPENS
# 1                                                 NaN    LNT1S
# 2                                                 NaN    LNT2S
# 3                                                 NaN    LOBCS
# 4                                                 NaN   LSEBCS
# 5                                                 NaN      EWS
# 6                                                 NaN     TFWS
# 7                                                 NaN     GSCS
# 8                                                 NaN     GSTS
# 9                                                 NaN    GNT2S
# 10                                                NaN    GOBCS
# 11                                                NaN   GSEBCS
# 12                                                NaN   LOPENS
# 13                                                NaN     LSCS
# ...

# %%
CAP.to_excel("EXTRACTED DATA.xlsx")
