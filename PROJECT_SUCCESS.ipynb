# %% [markdown]
# <a href="https://colab.research.google.com/github/iiconic07/iiconic07/blob/main/PROJECT_SUCCESS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("project-CSV.csv" )

# %%
df
# Out:
#     Unnamed: 0                                                  0  \
# 0            0                                                NaN
# 1            1                                              D i r
# 2            2                                                NaN
# 3            3                                                NaN
# 4            4                                                NaN
# 5            5                                                NaN
# 6            6                                            Status:
# 7            7                                                NaN
# 8            8                                              Stage
# 9            9                                                NaN
# 10          10                                                  I
# 11          11                                                NaN
# 12          12                                                NaN
# ...

# %%
df1 = df.drop("Unnamed: 0",axis=1)

# %%
df1
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                               D i r
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                             Status:
# 7                                                 NaN
# 8                                               Stage
# 9                                                 NaN
# 10                                                  I
# 11                                                NaN
# 12                                                NaN
# 13                                            Status:
# 14                                                NaN
# 15                                              Stage
# ...

# %%
program = df1.loc[4]

# %%
df11=df1.loc[5]

# %%
df12=df11.iloc[1:2]

# %%
df12.dropna
# Out:
# <bound method Series.dropna of 1    1002 - Government College of Engineering, Amra...
# Name: 4, dtype: object>

# %%
df13=df1.loc[16]

# %%
df14=df13.iloc[1:16]

# %%
df14.dropna
# Out:
# <bound method Series.dropna of 1      7194
# 2     14267
# 3     33295
# 4     13821
# 5      9776
# 6     14168
# 7     13239
# 8      8849
# 9     11544
# 10    11926
# 11    18357
# 12    85591
# 13    14226
# 14    21098
# 15    12158
# Name: 16, dtype: object>

# %%
df44=df1.iloc[11]

# %%
df45=df44.iloc[1:16]

# %%
df45.dropna
# Out:
# <bound method Series.dropna of 1     (93.5194774)
# 2     (85.9439612)
# 3     (49.2624002)
# 4     (88.5891094)
# 5     (92.1547185)
# 6     (82.5517986)
# 7     (93.2348660)
# 8     (86.0540400)
# 9     (74.6087498)
# 10    (88.5735391)
# 11    (80.7275334)
# 12    (92.7054742)
# 13    (74.6601682)
# 14    (43.5611190)
# 15    (94.8226791)
# Name: 11, dtype: object>

# %%
dfR=df1.loc[4]

# %%
dfG=dfR.iloc[1:2]

# %%
dfG.dropna
# Out:
# <bound method Series.dropna of 1    1002 - Government College of Engineering, Amra...
# Name: 4, dtype: object>

# %%
dfG
# Out:
# 1    1002 - Government College of Engineering, Amra...
# Name: 4, dtype: object

# %%
df4=df1.loc[8]

# %%
df5 = df4.iloc[1:16]

# %%
df5.dropna
# Out:
# <bound method Series.dropna of 1     GOPENS
# 2       GSCS
# 3       GSTS
# 4      GNT2S
# 5      GOBCS
# 6     GSEBCS
# 7     LOPENS
# 8       LSCS
# 9       LSTS
# 10     LNT1S
# 11     LNT2S
# 12     LOBCS
# 13    LSEBCS
# 14       EWS
# 15      TFWS
# Name: 8, dtype: object>

# %%
df5
# Out:
# 1     GOPENS
# 2       GSCS
# 3       GSTS
# 4      GNT2S
# 5      GOBCS
# 6     GSEBCS
# 7     LOPENS
# 8       LSCS
# 9       LSTS
# 10     LNT1S
# 11     LNT2S
# 12     LOBCS
# 13    LSEBCS
# 14       EWS
# 15      TFWS
# Name: 8, dtype: object

# %%
df8=df1.loc[9]

# %%
df9 = df8.iloc[1:16]

# %%
df9.dropna
# Out:
# <bound method Series.dropna of 1     13660
# 2     25951
# 3     54048
# 4     22245
# 5     16212
# 6     29954
# 7     14218
# 8     25812
# 9     37498
# 10    22274
# 11    31875
# 12    15197
# 13    37467
# 14    57153
# 15    11071
# Name: 9, dtype: object>

# %%
from pandas.io.parsers import c_parser_wrapper
c_parser_wrapper 
CAP= pd.DataFrame({ "Institute Name": dfG, "Category": df5 , "Program":df12,"Closing-Rank":df14,"Closing-Percentile":df45})

# %%
CAP
# Out:
#                                        Institute Name Category  \
# 1   1002 - Government College of Engineering, Amra...   GOPENS
# 10                                                NaN    LNT1S
# 11                                                NaN    LNT2S
# 12                                                NaN    LOBCS
# 13                                                NaN   LSEBCS
# 14                                                NaN      EWS
# 15                                                NaN     TFWS
# 2                                                 NaN     GSCS
# 3                                                 NaN     GSTS
# 4                                                 NaN    GNT2S
# 5                                                 NaN    GOBCS
# 6                                                 NaN   GSEBCS
# 7                                                 NaN   LOPENS
# 8                                                 NaN     LSCS
# ...

# %%
CAP.to_excel("project-tt.xlsx")
